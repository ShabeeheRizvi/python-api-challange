# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
from api_keys import g_key

# Incorpweather_api_keyorated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base URL to work off                         
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Counter to go through data
record = 0
sets = 1

# Create DataFrame
weather_df = pd.DataFrame({"City": cities})

weather_df["Country"] = ""
weather_df["Date"] = ""      
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Max Temp (F)"] = ""
weather_df["Wind Speed (mph)"] = ""


# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")


for index, row in weather_df.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    weather_response = requests.get(query_url).json()
 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        #print (query_url) 
        
        weather_df.loc[index, "Country"] = weather_response["sys"]["country"]     
        weather_df.loc[index, "Date"] = datetime.datetime.fromtimestamp(weather_response["dt"])
        weather_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        weather_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        weather_df.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        weather_df.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        weather_df.loc[index, "Max Temp (F)"] = 1.8 * (weather_response["main"]["temp_max"] - 273) + 32
        weather_df.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
               
    except:
        print(f"City not found...skipping {city}.")
        #print (query_url) 
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | tsihombe.
# City not found...skipping tsihombe.
# Processing Record 1  of Set 1 | vila do maio.
# Processing Record 2  of Set 1 | feijo.
# Processing Record 3  of Set 1 | taywarah.
# Processing Record 4  of Set 1 | upernavik.
# Processing Record 5  of Set 1 | ushuaia.
# Processing Record 6  of Set 1 | butaritari.
# Processing Record 7  of Set 1 | amderma.
# City not found...skipping amderma.
# Processing Record 8  of Set 1 | saldanha.
# Processing Record 9  of Set 1 | punta arenas.
# Processing Record 10  of Set 1 | hithadhoo.
# Processing Record 11  of Set 1 | bluff.
# Processing Record 12  of Set 1 | khorinsk.
# Processing Record 13  of Set 1 | meulaboh.
# Processing Record 14  of Set 1 | tasiilaq.
# Processing Record 15  of Set 1 | rikitea.
# Processing Record 16  of Set 1 | husavik.
# Processing Record 17  of Set 1 | broken hill.
# Processing Record 18  of Set 1 | puerto ayora.
# Processing Record 19  of Set 1 | berlevag.
# Processing Record 20  of Set 1 | hermanus.
# Processing Record 21  of Set 1 | touros.
# Processing Record 22  of Set 1 | bredasdorp.
# Processing Record 23  of Set 1 | vaini.
# Processing Record 24  of Set 1 | busselton.
# Processing Record 25  of Set 1 | palmer.
# Processing Record 26  of Set 1 | naze.
# Processing Record 27  of Set 1 | castro.
# Processing Record 28  of Set 1 | nizwa.
# Processing Record 29  of Set 1 | avarua.
# Processing Record 30  of Set 1 | toliary.
# City not found...skipping toliary.
# Processing Record 31  of Set 1 | arraial do cabo.
# Processing Record 32  of Set 1 | samusu.
# City not found...skipping samusu.
# Processing Record 33  of Set 1 | srednekolymsk.
# Processing Record 34  of Set 1 | chipinge.
# Processing Record 35  of Set 1 | taolanaro.
# City not found...skipping taolanaro.
# Processing Record 36  of Set 1 | hilo.
# Processing Record 37  of Set 1 | yellowknife.
# Processing Record 38  of Set 1 | mahebourg.
# Processing Record 39  of Set 1 | tommot.
# Processing Record 40  of Set 1 | nouadhibou.
# Processing Record 41  of Set 1 | mataura.
# Processing Record 42  of Set 1 | torbay.
# Processing Record 43  of Set 1 | longyearbyen.
# Processing Record 44  of Set 1 | kapaa.
# Processing Record 45  of Set 1 | east london.
# Processing Record 46  of Set 1 | cidreira.
# Processing Record 47  of Set 1 | amethi.
# Processing Record 48  of Set 1 | severo-kurilsk.
# Processing Record 49  of Set 1 | kruisfontein.
# Processing Record 0  of Set 2 | albany.
# Processing Record 1  of Set 2 | nikolayevka.
# Processing Record 2  of Set 2 | bilibino.
# Processing Record 3  of Set 2 | georgetown.
# Processing Record 4  of Set 2 | bandarbeyla.
# Processing Record 5  of Set 2 | arawa.
# Processing Record 6  of Set 2 | codrington.
# Processing Record 7  of Set 2 | ostrovskoye.
# Processing Record 8  of Set 2 | grand haven.
# Processing Record 9  of Set 2 | tuktoyaktuk.
# Processing Record 10  of Set 2 | belushya guba.
# City not found...skipping belushya guba.
# Processing Record 11  of Set 2 | courtalam.
# City not found...skipping courtalam.
# Processing Record 12  of Set 2 | atuona.
# Processing Record 13  of Set 2 | san juan evangelista.
# Processing Record 14  of Set 2 | saint-philippe.
# Processing Record 15  of Set 2 | qaanaaq.
# Processing Record 16  of Set 2 | bethel.
# Processing Record 17  of Set 2 | opunake.
# Processing Record 18  of Set 2 | vostok.
# Processing Record 19  of Set 2 | mao.
# Processing Record 20  of Set 2 | dikson.
# Processing Record 21  of Set 2 | burns lake.
# Processing Record 22  of Set 2 | dong hoi.
# Processing Record 23  of Set 2 | grindavik.
# Processing Record 24  of Set 2 | dunedin.
# Processing Record 25  of Set 2 | cayenne.
# Processing Record 26  of Set 2 | mount gambier.
# Processing Record 27  of Set 2 | saint-augustin.
# Processing Record 28  of Set 2 | dokka.
# Processing Record 29  of Set 2 | vestmanna.
# Processing Record 30  of Set 2 | doka.
# Processing Record 31  of Set 2 | menongue.
# Processing Record 32  of Set 2 | hirara.
# Processing Record 33  of Set 2 | yar-sale.
# Processing Record 34  of Set 2 | pevek.
# Processing Record 35  of Set 2 | barrow.
# Processing Record 36  of Set 2 | tateyama.
# Processing Record 37  of Set 2 | ilulissat.
# Processing Record 38  of Set 2 | cape town.
# Processing Record 39  of Set 2 | giddalur.
# Processing Record 40  of Set 2 | longyan.
# Processing Record 41  of Set 2 | thompson.
# Processing Record 42  of Set 2 | dossor.
# Processing Record 43  of Set 2 | chokurdakh.
# Processing Record 44  of Set 2 | nishihara.
# Processing Record 45  of Set 2 | muros.
# Processing Record 46  of Set 2 | dangtu.
# Processing Record 47  of Set 2 | udachnyy.
# Processing Record 48  of Set 2 | barentsburg.
# City not found...skipping barentsburg.
# Processing Record 49  of Set 2 | bolungarvik.
# City not found...skipping bolungarvik.
# Processing Record 0  of Set 3 | port hardy.
# Processing Record 1  of Set 3 | haibowan.
# City not found...skipping haibowan.
# Processing Record 2  of Set 3 | lebu.
# Processing Record 3  of Set 3 | khatanga.
# Processing Record 4  of Set 3 | cedeno.
# Processing Record 5  of Set 3 | nizhneyansk.
# City not found...skipping nizhneyansk.
# Processing Record 6  of Set 3 | grand river south east.
# City not found...skipping grand river south east.
# Processing Record 7  of Set 3 | katsuura.
# Processing Record 8  of Set 3 | strezhevoy.
# Processing Record 9  of Set 3 | esperance.
# Processing Record 10  of Set 3 | geraldton.
# Processing Record 11  of Set 3 | zhitikara.
# City not found...skipping zhitikara.
# Processing Record 12  of Set 3 | camacupa.
# Processing Record 13  of Set 3 | hobart.
# Processing Record 14  of Set 3 | avera.
# Processing Record 15  of Set 3 | bundaberg.
# Processing Record 16  of Set 3 | saint-joseph.
# Processing Record 17  of Set 3 | llangefni.
# Processing Record 18  of Set 3 | jamestown.
# Processing Record 19  of Set 3 | leningradskiy.
# Processing Record 20  of Set 3 | itamaraca.
# Processing Record 21  of Set 3 | khani.
# Processing Record 22  of Set 3 | illoqqortoormiut.
# City not found...skipping illoqqortoormiut.
# Processing Record 23  of Set 3 | port moresby.
# Processing Record 24  of Set 3 | palabuhanratu.
# City not found...skipping palabuhanratu.
# Processing Record 25  of Set 3 | constitucion.
# Processing Record 26  of Set 3 | dicabisagan.
# Processing Record 27  of Set 3 | daru.
# Processing Record 28  of Set 3 | phaphund.
# Processing Record 29  of Set 3 | le vauclin.
# Processing Record 30  of Set 3 | cabo san lucas.
# Processing Record 31  of Set 3 | keetmanshoop.
# Processing Record 32  of Set 3 | saint-francois.
# Processing Record 33  of Set 3 | chaiyaphum.
# Processing Record 34  of Set 3 | victoria.
# Processing Record 35  of Set 3 | kapuskasing.
# Processing Record 36  of Set 3 | sungaipenuh.
# Processing Record 37  of Set 3 | uyuni.
# Processing Record 38  of Set 3 | valerianovsk.
# Processing Record 39  of Set 3 | new norfolk.
# Processing Record 40  of Set 3 | vaitupu.
# City not found...skipping vaitupu.
# Processing Record 41  of Set 3 | mar del plata.
# Processing Record 42  of Set 3 | padang.
# Processing Record 43  of Set 3 | fortuna.
# Processing Record 44  of Set 3 | tiksi.
# Processing Record 45  of Set 3 | puerto ayacucho.
# Processing Record 46  of Set 3 | les cayes.
# Processing Record 47  of Set 3 | port alfred.
# Processing Record 48  of Set 3 | chuy.
# Processing Record 49  of Set 3 | bababe.
# City not found...skipping bababe.
# Processing Record 0  of Set 4 | saint george.
# Processing Record 1  of Set 4 | faanui.
# Processing Record 2  of Set 4 | luanda.
# Processing Record 3  of Set 4 | ust-ilimsk.
# Processing Record 4  of Set 4 | bloomington.
# Processing Record 5  of Set 4 | quelimane.
# Processing Record 6  of Set 4 | hami.
# Processing Record 7  of Set 4 | west bay.
# Processing Record 8  of Set 4 | petropavlovsk-kamchatskiy.
# Processing Record 9  of Set 4 | finschhafen.
# Processing Record 10  of Set 4 | tawang.
# Processing Record 11  of Set 4 | kautokeino.
# Processing Record 12  of Set 4 | mount isa.
# Processing Record 13  of Set 4 | saleaula.
# City not found...skipping saleaula.
# Processing Record 14  of Set 4 | kaitangata.
# Processing Record 15  of Set 4 | margate.
# Processing Record 16  of Set 4 | suhbaatar.
# Processing Record 17  of Set 4 | vila velha.
# Processing Record 18  of Set 4 | puerto escondido.
# Processing Record 19  of Set 4 | ribeira grande.
# Processing Record 20  of Set 4 | comodoro rivadavia.
# Processing Record 21  of Set 4 | bambous virieux.
# Processing Record 22  of Set 4 | el badari.
# City not found...skipping el badari.
# Processing Record 23  of Set 4 | rantepao.
# Processing Record 24  of Set 4 | kodiak.
# Processing Record 25  of Set 4 | ostersund.
# Processing Record 26  of Set 4 | ponta delgada.
# Processing Record 27  of Set 4 | kushima.
# Processing Record 28  of Set 4 | duluth.
# Processing Record 29  of Set 4 | mizan teferi.
# Processing Record 30  of Set 4 | lima.
# Processing Record 31  of Set 4 | saint-pierre.
# Processing Record 32  of Set 4 | nara.
# Processing Record 33  of Set 4 | anito.
# Processing Record 34  of Set 4 | varna.
# Processing Record 35  of Set 4 | cadillac.
# Processing Record 36  of Set 4 | kieta.
# Processing Record 37  of Set 4 | bagdarin.
# Processing Record 38  of Set 4 | talnakh.
# Processing Record 39  of Set 4 | balikpapan.
# Processing Record 40  of Set 4 | tuy hoa.
# Processing Record 41  of Set 4 | yashan.
# Processing Record 42  of Set 4 | belyy yar.
# Processing Record 43  of Set 4 | pochutla.
# Processing Record 44  of Set 4 | la rioja.
# Processing Record 45  of Set 4 | ukiah.
# Processing Record 46  of Set 4 | pilikwe.
# Processing Record 47  of Set 4 | gat.
# Processing Record 48  of Set 4 | kavieng.
# Processing Record 49  of Set 4 | deputatskiy.
# Processing Record 0  of Set 5 | tuatapere.
# Processing Record 1  of Set 5 | westport.
# Processing Record 2  of Set 5 | tiruchchendur.
# Processing Record 3  of Set 5 | port elizabeth.
# Processing Record 4  of Set 5 | mustafakemalpasa.
# Processing Record 5  of Set 5 | lagoa.
# Processing Record 6  of Set 5 | guangyuan.
# Processing Record 7  of Set 5 | vestmannaeyjar.
# Processing Record 8  of Set 5 | hebertville.
# City not found...skipping hebertville.
# Processing Record 9  of Set 5 | lompoc.
# Processing Record 10  of Set 5 | hualmay.
# Processing Record 11  of Set 5 | chippewa falls.
# Processing Record 12  of Set 5 | clyde river.
# Processing Record 13  of Set 5 | najran.
# Processing Record 14  of Set 5 | cacador.
# Processing Record 15  of Set 5 | vila.
# Processing Record 16  of Set 5 | tabiauea.
# City not found...skipping tabiauea.
# Processing Record 17  of Set 5 | nuuk.
# Processing Record 18  of Set 5 | rawson.
# Processing Record 19  of Set 5 | kizukuri.
# Processing Record 20  of Set 5 | sur.
# Processing Record 21  of Set 5 | port hueneme.
# Processing Record 22  of Set 5 | airai.
# Processing Record 23  of Set 5 | caravelas.
# Processing Record 24  of Set 5 | wenling.
# Processing Record 25  of Set 5 | hasaki.
# Processing Record 26  of Set 5 | yerbogachen.
# Processing Record 27  of Set 5 | krosno odrzanskie.
# Processing Record 28  of Set 5 | metro.
# Processing Record 29  of Set 5 | ust-nera.
# Processing Record 30  of Set 5 | mahibadhoo.
# Processing Record 31  of Set 5 | nelson bay.
# Processing Record 32  of Set 5 | beibei.
# Processing Record 33  of Set 5 | gao.
# Processing Record 34  of Set 5 | karaul.
# City not found...skipping karaul.
# Processing Record 35  of Set 5 | nikolskoye.
# Processing Record 36  of Set 5 | haines junction.
# Processing Record 37  of Set 5 | souillac.
# Processing Record 38  of Set 5 | henties bay.
# Processing Record 39  of Set 5 | samarai.
# Processing Record 40  of Set 5 | almeirim.
# Processing Record 41  of Set 5 | iqaluit.
# Processing Record 42  of Set 5 | hofn.
# Processing Record 43  of Set 5 | provideniya.
# Processing Record 44  of Set 5 | ravenna.
# Processing Record 45  of Set 5 | tamale.
# Processing Record 46  of Set 5 | bengkulu.
# Processing Record 47  of Set 5 | hovd.
# Processing Record 48  of Set 5 | harper.
# Processing Record 49  of Set 5 | kuusamo.
# Processing Record 0  of Set 6 | namanyere.
# Processing Record 1  of Set 6 | izumo.
# Processing Record 2  of Set 6 | cherskiy.
# Processing Record 3  of Set 6 | passo de camaragibe.
# Processing Record 4  of Set 6 | macau.
# Processing Record 5  of Set 6 | jinhua.
# Processing Record 6  of Set 6 | ahumada.
# City not found...skipping ahumada.
# Processing Record 7  of Set 6 | eureka.
# Processing Record 8  of Set 6 | san quintin.
# Processing Record 9  of Set 6 | manassas park.
# Processing Record 10  of Set 6 | laguna.
# Processing Record 11  of Set 6 | san jose.
# Processing Record 12  of Set 6 | sharqpur.
# Processing Record 13  of Set 6 | sentyabrskiy.
# City not found...skipping sentyabrskiy.
# Processing Record 14  of Set 6 | fairbanks.
# Processing Record 15  of Set 6 | lavrentiya.
# Processing Record 16  of Set 6 | ambovombe.
# Processing Record 17  of Set 6 | chilca.
# Processing Record 18  of Set 6 | diego de almagro.
# Processing Record 19  of Set 6 | pangai.
# Processing Record 20  of Set 6 | matay.
# Processing Record 21  of Set 6 | narsingdi.
# Processing Record 22  of Set 6 | batticaloa.
# Processing Record 23  of Set 6 | utiroa.
# City not found...skipping utiroa.
# Processing Record 24  of Set 6 | umm lajj.
# Processing Record 25  of Set 6 | sambava.
# Processing Record 26  of Set 6 | binabalian.
# Processing Record 27  of Set 6 | barabai.
# Processing Record 28  of Set 6 | turukhansk.
# Processing Record 29  of Set 6 | gorno-chuyskiy.
# City not found...skipping gorno-chuyskiy.
# Processing Record 30  of Set 6 | attawapiskat.
# City not found...skipping attawapiskat.
# Processing Record 31  of Set 6 | bloomfield.
# Processing Record 32  of Set 6 | elko.
# Processing Record 33  of Set 6 | ahipara.
# Processing Record 34  of Set 6 | le moule.
# Processing Record 35  of Set 6 | morondava.
# Processing Record 36  of Set 6 | narsaq.
# Processing Record 37  of Set 6 | vila franca do campo.
# Processing Record 38  of Set 6 | kunming.
# Processing Record 39  of Set 6 | severodvinsk.
# Processing Record 40  of Set 6 | merauke.
# Processing Record 41  of Set 6 | itarema.
# Processing Record 42  of Set 6 | zeya.
# Processing Record 43  of Set 6 | jijiga.
# Processing Record 44  of Set 6 | zhuanghe.
# Processing Record 45  of Set 6 | benevento.
# Processing Record 46  of Set 6 | el grullo.
# Processing Record 47  of Set 6 | cockburn town.
# Processing Record 48  of Set 6 | plettenberg bay.
# Processing Record 49  of Set 6 | mbanza-ngungu.
# Processing Record 0  of Set 7 | poum.
# Processing Record 1  of Set 7 | bayir.
# Processing Record 2  of Set 7 | roald.
# Processing Record 3  of Set 7 | redlands.
# Processing Record 4  of Set 7 | korla.
# Processing Record 5  of Set 7 | salalah.
# Processing Record 6  of Set 7 | nalut.
# Processing Record 7  of Set 7 | aklavik.
# Processing Record 8  of Set 7 | mayumba.
# Processing Record 9  of Set 7 | flinders.
# Processing Record 10  of Set 7 | praia.
# Processing Record 11  of Set 7 | antofagasta.
# Processing Record 12  of Set 7 | xinqing.
# Processing Record 13  of Set 7 | cam ranh.
# Processing Record 14  of Set 7 | akureyri.
# Processing Record 15  of Set 7 | santa maria.
# Processing Record 16  of Set 7 | farafangana.
# Processing Record 17  of Set 7 | kapoeta.
# Processing Record 18  of Set 7 | chicama.
# Processing Record 19  of Set 7 | zhuhai.
# Processing Record 20  of Set 7 | cap malheureux.
# Processing Record 21  of Set 7 | saskylakh.
# Processing Record 22  of Set 7 | totma.
# Processing Record 23  of Set 7 | ishinomaki.
# Processing Record 24  of Set 7 | catamarca.
# Processing Record 25  of Set 7 | huilong.
# Processing Record 26  of Set 7 | gizo.
# Processing Record 27  of Set 7 | raudeberg.
# Processing Record 28  of Set 7 | praia da vitoria.
# Processing Record 29  of Set 7 | martaban.
# Processing Record 30  of Set 7 | nivala.
# Processing Record 31  of Set 7 | kupang.
# Processing Record 32  of Set 7 | nome.
# Processing Record 33  of Set 7 | praya.
# Processing Record 34  of Set 7 | gamboma.
# Processing Record 35  of Set 7 | ancud.
# Processing Record 36  of Set 7 | brae.
# Processing Record 37  of Set 7 | saryshagan.
# City not found...skipping saryshagan.
# Processing Record 38  of Set 7 | santa cruz.
# Processing Record 39  of Set 7 | mangai.
# Processing Record 40  of Set 7 | mango.
# Processing Record 41  of Set 7 | sao paulo de olivenca.
# Processing Record 42  of Set 7 | half moon bay.
# Processing Record 43  of Set 7 | pahrump.
# Processing Record 44  of Set 7 | dongobesh.
# Processing Record 45  of Set 7 | torrelavega.
# Processing Record 46  of Set 7 | kununurra.
# Processing Record 47  of Set 7 | lazaro cardenas.
# Processing Record 48  of Set 7 | tinde.
# Processing Record 49  of Set 7 | trofors.
# Processing Record 0  of Set 8 | kolyvan.
# Processing Record 1  of Set 8 | vangaindrano.
# Processing Record 2  of Set 8 | wukari.
# Processing Record 3  of Set 8 | havoysund.
# Processing Record 4  of Set 8 | pierre.
# Processing Record 5  of Set 8 | galle.
# Processing Record 6  of Set 8 | pamanukan.
# Processing Record 7  of Set 8 | borogontsy.
# Processing Record 8  of Set 8 | boz.
# Processing Record 9  of Set 8 | gubkinskiy.
# Processing Record 10  of Set 8 | khasan.
# Processing Record 11  of Set 8 | zdvinsk.
# Processing Record 12  of Set 8 | hobyo.
# Processing Record 13  of Set 8 | louisbourg.
# City not found...skipping louisbourg.
# Processing Record 14  of Set 8 | grand gaube.
# Processing Record 15  of Set 8 | lesozavodsk.
# Processing Record 16  of Set 8 | sechura.
# Processing Record 17  of Set 8 | klaksvik.
# Processing Record 18  of Set 8 | zambezi.
# Processing Record 19  of Set 8 | arrecife.
# Processing Record 20  of Set 8 | punto fijo.
# Processing Record 21  of Set 8 | maldonado.
# Processing Record 22  of Set 8 | inderborskiy.
# City not found...skipping inderborskiy.
# Processing Record 23  of Set 8 | raga.
# Processing Record 24  of Set 8 | nabire.
# Processing Record 25  of Set 8 | tulu bolo.
# Processing Record 26  of Set 8 | phalombe.
# Processing Record 27  of Set 8 | svetlogorsk.
# Processing Record 28  of Set 8 | mehamn.
# Processing Record 29  of Set 8 | norrtalje.
# Processing Record 30  of Set 8 | sao gabriel da cachoeira.
# Processing Record 31  of Set 8 | moron.
# Processing Record 32  of Set 8 | strai.
# Processing Record 33  of Set 8 | las choapas.
# Processing Record 34  of Set 8 | coquimbo.
# Processing Record 35  of Set 8 | yanan.
# City not found...skipping yanan.
# Processing Record 36  of Set 8 | cabot.
# Processing Record 37  of Set 8 | jiayuguan.
# Processing Record 38  of Set 8 | yumen.
# Processing Record 39  of Set 8 | sahrak.
# City not found...skipping sahrak.
# Processing Record 40  of Set 8 | san cristobal.
# Processing Record 41  of Set 8 | sitka.
# Processing Record 42  of Set 8 | port blair.
# Processing Record 43  of Set 8 | ahuimanu.
# Processing Record 44  of Set 8 | luderitz.
# Processing Record 45  of Set 8 | grand centre.
# City not found...skipping grand centre.
# Processing Record 46  of Set 8 | zabaykalsk.
# Processing Record 47  of Set 8 | usevya.
# Processing Record 48  of Set 8 | tura.
# Processing Record 49  of Set 8 | la reforma.
# Processing Record 0  of Set 9 | cairns.
# Processing Record 1  of Set 9 | berwick.
# Processing Record 2  of Set 9 | waddan.
# Processing Record 3  of Set 9 | hay river.
# Processing Record 4  of Set 9 | palana.
# Processing Record 5  of Set 9 | los llanos de aridane.
# Processing Record 6  of Set 9 | maningrida.
# Processing Record 7  of Set 9 | ngukurr.
# City not found...skipping ngukurr.
# Processing Record 8  of Set 9 | kahului.
# Processing Record 9  of Set 9 | issaquah.
# Processing Record 10  of Set 9 | okhotsk.
# Processing Record 11  of Set 9 | pobe.
# Processing Record 12  of Set 9 | marzuq.
# Processing Record 13  of Set 9 | gayeri.
# Processing Record 14  of Set 9 | oksfjord.
# Processing Record 15  of Set 9 | douentza.
# Processing Record 16  of Set 9 | chapais.
# Processing Record 17  of Set 9 | asau.
# Processing Record 18  of Set 9 | egvekinot.
# Processing Record 19  of Set 9 | pskov.
# Processing Record 20  of Set 9 | waingapu.
# Processing Record 21  of Set 9 | eisiskes.
# Processing Record 22  of Set 9 | istok.
# Processing Record 23  of Set 9 | birao.
# Processing Record 24  of Set 9 | vanimo.
# Processing Record 25  of Set 9 | nuevitas.
# Processing Record 26  of Set 9 | baykit.
# Processing Record 27  of Set 9 | svetlyy.
# Processing Record 28  of Set 9 | turinsk.
# Processing Record 29  of Set 9 | sabancuy.
# Processing Record 30  of Set 9 | mbekenyera.
# Processing Record 31  of Set 9 | wanaka.
# Processing Record 32  of Set 9 | oostburg.
# Processing Record 33  of Set 9 | heilbron.
# Processing Record 34  of Set 9 | mys shmidta.
# City not found...skipping mys shmidta.
# Processing Record 35  of Set 9 | brindisi.
# Processing Record 36  of Set 9 | seabra.
# Processing Record 37  of Set 9 | wanning.
# Processing Record 38  of Set 9 | lusambo.
# Processing Record 39  of Set 9 | whitehorse.
# Processing Record 40  of Set 9 | bara.
# Processing Record 41  of Set 9 | balkhash.
# Processing Record 42  of Set 9 | rapar.
# Processing Record 43  of Set 9 | omboue.
# Processing Record 44  of Set 9 | ponta do sol.
# Processing Record 45  of Set 9 | devonport.
# Processing Record 46  of Set 9 | umm kaddadah.
# Processing Record 47  of Set 9 | marrakesh.
# Processing Record 48  of Set 9 | maragogi.
# Processing Record 49  of Set 9 | sortland.
# Processing Record 0  of Set 10 | benguela.
# Processing Record 1  of Set 10 | boa vista.
# Processing Record 2  of Set 10 | luang prabang.
# Processing Record 3  of Set 10 | boguchany.
# Processing Record 4  of Set 10 | milkovo.
# Processing Record 5  of Set 10 | qui nhon.
# Processing Record 6  of Set 10 | lorengau.
# Processing Record 7  of Set 10 | olafsvik.
# Processing Record 8  of Set 10 | samalaeulu.
# City not found...skipping samalaeulu.
# Processing Record 9  of Set 10 | monrovia.
# Processing Record 10  of Set 10 | santa isabel do rio negro.
# Processing Record 11  of Set 10 | moura.
# Processing Record 12  of Set 10 | san patricio.
# Processing Record 13  of Set 10 | alofi.
# Processing Record 14  of Set 10 | tallahassee.
# Processing Record 15  of Set 10 | lolua.
# City not found...skipping lolua.
# Processing Record 16  of Set 10 | tahta.
# Processing Record 17  of Set 10 | mecca.
# Processing Record 18  of Set 10 | emerald.
# Processing Record 19  of Set 10 | costinesti.
# Processing Record 20  of Set 10 | lawton.
# Processing Record 21  of Set 10 | lerik.
# Processing Record 22  of Set 10 | souris.
# Processing Record 23  of Set 10 | oranjestad.
# Processing Record 24  of Set 10 | acapulco.
# Processing Record 25  of Set 10 | tumannyy.
# City not found...skipping tumannyy.
# Processing Record 26  of Set 10 | jacareacanga.
# Processing Record 27  of Set 10 | ulaangom.
# Processing Record 28  of Set 10 | ivot.
# Processing Record 29  of Set 10 | goure.
# Processing Record 30  of Set 10 | alugan.
# Processing Record 31  of Set 10 | yaan.
# Processing Record 32  of Set 10 | falealupo.
# City not found...skipping falealupo.
# Processing Record 33  of Set 10 | lubao.
# Processing Record 34  of Set 10 | knysna.
# Processing Record 35  of Set 10 | khandyga.
# Processing Record 36  of Set 10 | madimba.
# Processing Record 37  of Set 10 | dalbandin.
# Processing Record 38  of Set 10 | vardo.
# Processing Record 39  of Set 10 | bangangte.
# Processing Record 40  of Set 10 | the pas.
# Processing Record 41  of Set 10 | kidal.
# Processing Record 42  of Set 10 | bathsheba.
# Processing Record 43  of Set 10 | talgar.
# Processing Record 44  of Set 10 | nguiu.
# City not found...skipping nguiu.
# Processing Record 45  of Set 10 | mixtequilla.
# City not found...skipping mixtequilla.
# Processing Record 46  of Set 10 | palauig.
# Processing Record 47  of Set 10 | portland.
# Processing Record 48  of Set 10 | quatre cocos.
# Processing Record 49  of Set 10 | araceli.
# Processing Record 0  of Set 11 | blagoyevo.
# Processing Record 1  of Set 11 | manicore.
# Processing Record 2  of Set 11 | tyrma.
# Processing Record 3  of Set 11 | saint-michel-des-saints.
# Processing Record 4  of Set 11 | eregli.
# Processing Record 5  of Set 11 | kristiansund.
# Processing Record 6  of Set 11 | pisco.
# Processing Record 7  of Set 11 | uk.
# City not found...skipping uk.
# Processing Record 8  of Set 11 | port hedland.
# Processing Record 9  of Set 11 | matara.
# Processing Record 10  of Set 11 | burica.
# City not found...skipping burica.
# Processing Record 11  of Set 11 | amga.
# Processing Record 12  of Set 11 | warqla.
# City not found...skipping warqla.
# Processing Record 13  of Set 11 | darab.
# Processing Record 14  of Set 11 | karratha.
# Processing Record 15  of Set 11 | sao filipe.
# Processing Record 16  of Set 11 | vetluzhskiy.
# Processing Record 17  of Set 11 | kurilsk.
# Processing Record 18  of Set 11 | salumbar.
# Processing Record 19  of Set 11 | san javier.
# Processing Record 20  of Set 11 | kerema.
# Processing Record 21  of Set 11 | port lincoln.
# Processing Record 22  of Set 11 | tukrah.
# Processing Record 23  of Set 11 | emilio carranza.
# Processing Record 24  of Set 11 | senges.
# Processing Record 25  of Set 11 | yarensk.
# Processing Record 26  of Set 11 | yuci.
# Processing Record 27  of Set 11 | malya.
# Processing Record 28  of Set 11 | natal.
# Processing Record 29  of Set 11 | ust-tsilma.
# Processing Record 30  of Set 11 | pangody.
# Processing Record 31  of Set 11 | tarauaca.
# Processing Record 32  of Set 11 | byron bay.
# Processing Record 33  of Set 11 | tessalit.
# Processing Record 34  of Set 11 | wicklow.
# Processing Record 35  of Set 11 | beloha.
# Processing Record 36  of Set 11 | houma.
# Processing Record 37  of Set 11 | denpasar.
# Processing Record 38  of Set 11 | mgachi.
# Processing Record 39  of Set 11 | opuwo.
# Processing Record 40  of Set 11 | grootegast.
# Processing Record 41  of Set 11 | maroantsetra.
# Processing Record 42  of Set 11 | sangar.
# Processing Record 43  of Set 11 | ambatondrazaka.
# Processing Record 44  of Set 11 | westerland.
# Processing Record 45  of Set 11 | mapiripan.
# Processing Record 46  of Set 11 | ulcinj.
# Processing Record 47  of Set 11 | santa fe.
# Processing Record 48  of Set 11 | sorland.
# Processing Record 49  of Set 11 | de-kastri.
# Processing Record 0  of Set 12 | norman wells.
# Processing Record 1  of Set 12 | viransehir.
# Processing Record 2  of Set 12 | smithers.
# Processing Record 3  of Set 12 | nanortalik.
# Processing Record 4  of Set 12 | auchtermuchty.
# Processing Record 5  of Set 12 | trairi.
# Processing Record 6  of Set 12 | vavoua.
# Processing Record 7  of Set 12 | shimoda.
# Processing Record 8  of Set 12 | carnarvon.
# Processing Record 9  of Set 12 | richards bay.
# Processing Record 10  of Set 12 | bad sankt leonhard.
# City not found...skipping bad sankt leonhard.
# Processing Record 11  of Set 12 | powell river.
# Processing Record 12  of Set 12 | san joaquin.
# Processing Record 13  of Set 12 | darnah.
# Processing Record 14  of Set 12 | surt.
# Processing Record 15  of Set 12 | huanren.
# Processing Record 16  of Set 12 | kudahuvadhoo.
# Processing Record 17  of Set 12 | pangnirtung.
# Processing Record 18  of Set 12 | kaliua.
# Processing Record 19  of Set 12 | alyangula.
# Processing Record 20  of Set 12 | makakilo city.
# Processing Record 21  of Set 12 | fuyang.
# Processing Record 22  of Set 12 | hongjiang.
# Processing Record 23  of Set 12 | ntcheu.
# Processing Record 24  of Set 12 | mizdah.
# Processing Record 25  of Set 12 | hervey bay.
# Processing Record 26  of Set 12 | longido.
# Processing Record 27  of Set 12 | puerto madryn.
# Processing Record 28  of Set 12 | san ramon.
# Processing Record 29  of Set 12 | nizhniy kuranakh.
# Processing Record 30  of Set 12 | yokadouma.
# Processing Record 31  of Set 12 | vao.
# Processing Record 32  of Set 12 | bihariganj.
# Processing Record 33  of Set 12 | juneau.
# Processing Record 34  of Set 12 | hojai.
# Processing Record 35  of Set 12 | kapit.
# Processing Record 36  of Set 12 | aasiaat.
# Processing Record 37  of Set 12 | tazovskiy.
# Processing Record 38  of Set 12 | waunakee.
# Processing Record 39  of Set 12 | krasnyy yar.
# Processing Record 40  of Set 12 | fort nelson.
# Processing Record 41  of Set 12 | buraydah.
# Processing Record 42  of Set 12 | isangel.
# Processing Record 43  of Set 12 | north bend.
# Processing Record 44  of Set 12 | setermoen.
# Processing Record 45  of Set 12 | el carmen.
# Processing Record 46  of Set 12 | bugulma.
# Processing Record 47  of Set 12 | marcona.
# City not found...skipping marcona.
# Processing Record 48  of Set 12 | havelock.
# Processing Record 49  of Set 12 | okandja.
# City not found...skipping okandja.
# Processing Record 0  of Set 13 | atlantic city.
# Processing Record 1  of Set 13 | skiros.
# City not found...skipping skiros.
# Processing Record 2  of Set 13 | jalu.
# Processing Record 3  of Set 13 | bintulu.
# Processing Record 4  of Set 13 | umzimvubu.
# City not found...skipping umzimvubu.
# Processing Record 5  of Set 13 | bosaso.
# Processing Record 6  of Set 13 | eyl.
# Processing Record 7  of Set 13 | aktash.
# Processing Record 8  of Set 13 | arkhangelsk.
# Processing Record 9  of Set 13 | innisfail.
# Processing Record 10  of Set 13 | orange cove.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Data Count
weather_df.count()
# Out:
# City                611
# Country             611
# Date                611
# Latitude            611
# Longitude           611
# Cloudiness (%)      611
# Humidity (%)        611
# Max Temp (F)        611
# Wind Speed (mph)    611
# dtype: int64

# %%
# Display DataFrame
weather_df.head()
# Out:
#            City Country                 Date Latitude Longitude  \
# 0      tsihombe
# 1  vila do maio      CV  2020-04-14 13:04:48    15.13    -23.22
# 2         feijo      BR  2020-04-14 13:04:49    -8.16    -70.35
# 3      taywarah      AF  2020-04-14 13:04:49    33.35     64.42
# 4     upernavik      GL  2020-04-14 13:04:49    72.79    -56.15
#
#   Cloudiness (%) Humidity (%) Max Temp (F) Wind Speed (mph)
# 0
# 1             75           51        82.67             10.3
# 2              6           48       91.544             2.52
# 3             54           40       39.956             1.38
# 4            100           94       24.404             3.98

# %%
# Convert data strings to float
pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float)
pd.to_numeric(weather_df["Humidity (%)"]).astype(float)
pd.to_numeric(weather_df["Latitude"]).astype(float)
pd.to_numeric(weather_df["Longitude"]).astype(float)
pd.to_numeric(weather_df["Max Temp (F)"]).astype(float)
pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float)
weather_df

#Export DataFrame to CSV File
weather_df.to_csv("weather_df.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature ({today})")
plt.grid(True)
print("The plot proves that as we generally move away from the equator, temperature drops")
# Out:
# The plot proves that as we generally move away from the equator, temperature drops

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Humidity (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) ({today})")
plt.grid(True)
print("The plot shows that there is no real pattern that can describe the relationship between latitude and humidity")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and humidity

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")
plt.grid(True)
print("The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")
plt.grid(True)
print("The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -1.06x + 97.51
# The r-squared is: -0.8832120562642449
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.57x + 82.92
# The r-squared is: 0.725172750463841
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.47x + 45.44
# The r-squared is: 0.3949043882802023
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.13x + 74.45
# The r-squared is: 0.09456957568247225
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.44x + 36.66
# The r-squared is: 0.2518087061809958
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.44x + 66.06
# The r-squared is: 0.16195629002110593
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.02x + 3.2
# The r-squared is: 0.11373559820567133
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.05x + 2.23
# The r-squared is: -0.29413042540313705
# The regression does not display much of a correlation between the data sets.
